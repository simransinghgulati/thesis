# %% [markdown]
# # Forecasting in Cryptocurrencies
#
# In this notebook I am trying to predict the Bitcoin volatility and its potential influencers.
#
# These determinants range from a variety of categories as listed below:
#
# * Blockchain Attributes
#     1. Mining Profitability
#     2. Number of Transactions
#     3. Market Capitalisation
#     4. Transacation Size
#         - Average
#         - Median
#     5. Average Transaction Value
#     6. Confirmation Time
#     7. Block Size
#     8. Fee Reward
#     9. Hash Rate
#     10. Number of active-addresses
#
#
# * Public Opinion
#     1. Number of Tweets
#     2. Google Searches
#
#
# * Macro-Economical Factors
#     1. NASDAQ
#     2. Gold Price
#     3. Crude Oil
#     4. Major Stocks
#         - S&P500
#         - DOW30
#         - FTSE
#
#
# * Fiat Currencies
#     1. Euro
#     2. Pound
#     3. Japanbese Yen
#     4. Chinese Yen
#     5. Swiss Franc
#
# An important and very crucial aspect of this project would be to fetch the above listed datasets, and put them in a combined table.
#
# We start with importing the relevant libraries.

# %%
# Libraries

import numpy as np
import pandas as pd

# API to Yahoo Finance
import yfinance as yf

# %% [markdown]
# ## Data Acquisistion
#
# There's a total of 30 time-series that we scrape from the internet. We fetch the information from two major sources:
#
# 1.BitInfoCharts
#
# 2.Yahoo Finance
#
# The dynamic web-graphs from [bitinfocharts](https://bitinfocharts.com) were scraped with the help of [this](https://github.com/logic-language/bitinfochartscraper) GitHub repository.
#
# And [Yahoo Finance](https://finance.yahoo.com), it has a very nice python package available [here](https://pypi.org/project/yfinance/) which makes an API call to download data.

# %%
bitinfo_df = pd.read_csv('data/bitcoin.csv',index_col=0)

# %%
pd.set_option("display.max_columns", None)

# %%
bitinfo_df.head()
# Out:
#          date  mining_profitability  transactions  market_cap  sent_addresses  \
# 0  2010/07/17              154298.0         235.0    169839.0           390.0
# 1  2010/07/18              401834.0         248.0    249761.0           424.0
# 2  2010/07/19              481473.0         354.0    295981.0           553.0
# 3  2010/07/20              431831.0         413.0    270546.0           632.0
# 4  2010/07/21              460783.0         256.0    265900.0           440.0
#
#    av_transaction_size  median_transaction_size  send_usd      hashrate  \
# 0                  NaN                      NaN    1193.0  2.775561e+09
# 1                  NaN                      NaN    2612.0  1.554461e+09
# 2                  NaN                      NaN    4047.0  1.551287e+09
# 3                  NaN                      NaN    2341.0  1.640430e+09
# 4                  NaN                      NaN    2122.0  1.723493e+09
#
#    top_100_percent  confirmation_time  block_size  tweets  \
# ...

# %%
bitinfo_df['Date'] = pd.to_datetime(bitinfo_df['date'])

# %%
bitinfo_df.describe()
# Out:
#        mining_profitability   transactions    market_cap  sent_addresses  \
# count           4005.000000    4305.000000  4.005000e+03     4558.000000
# mean            5962.989555  151587.212311  8.954528e+10   209817.202062
# std            27370.823431  126185.939427  1.887187e+11   189968.899771
# min                0.063700       1.000000  1.698390e+05        1.000000
# 25%                0.338000   31229.000000  9.590784e+08    13884.500000
# 50%                2.102000  124773.000000  7.667305e+09   167898.500000
# 75%             2323.000000  271445.000000  1.189676e+11   380153.750000
# max           481473.000000  490459.000000  1.185187e+12   730199.000000
#
#        av_transaction_size  median_transaction_size      send_usd  \
# count                  0.0             3.361000e+03  4.005000e+03
# mean                   NaN             1.150912e+00  3.817764e+09
# std                    NaN             3.046334e+00  7.558539e+09
# ...

# %%
bitinfo_df.drop(['av_transaction_size', 'full_name', 'coin', 'date'],axis=1,inplace=True)

# %%
# bitinfo_df.plot(x='Date',subplots=True, layout = (6,3), figsize=(15,10))

# %%
bitinfo_df = bitinfo_df.sort_values('Date')

# %%
bitinfo_df = bitinfo_df[bitinfo_df['date']>'2011-07-01']

# %%
bitinfo_df['mining_profitability']
# Out:
# 350     10885.000
# 351     11113.000
# 352     11129.000
# 353      8661.000
# 354     10222.000
#           ...
# 4001        0.243
# 4002        0.257
# 4003        0.209
# 4004        0.378
# 4565          NaN
# Name: mining_profitability, Length: 3656, dtype: float64

# %%
np.where(pd.isnull(bitinfo_df['mining_profitability']))
# Out:
# (array([3655]),)

# %%
tickers = ['CHFUSD=X', 'EURUSD=X', 'GBPUSD=X', 'JPY=X', 'CNY=X','^DJI', '^FTSE','CL=F', '^GSPC', '^IXIC', 'GC=F']

# %%
yahoo_df = yf.download(tickers, start='2010-01-01')
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
yahoo_df.head()
# Out:
#            Adj Close                                                      \
#             CHFUSD=X       CL=F   CNY=X  EURUSD=X  GBPUSD=X         GC=F
# Date
# 2009-12-31  0.966931  79.360001  6.8305  1.432706  1.618202  1095.199951
# 2010-01-01  0.967211        NaN     NaN  1.438994  1.613294          NaN
# 2010-01-04  0.971723  81.510002  6.8169  1.442398  1.611370  1117.699951
# 2010-01-05  0.967399  81.769997  6.8170  1.436596  1.599079  1118.099976
# 2010-01-06  0.973141  83.180000  6.8183  1.440403  1.602384  1135.900024
#
#                                                                             \
#                 JPY=X          ^DJI        ^FTSE        ^GSPC        ^IXIC
# Date
# 2009-12-31  92.910004  10428.049805          NaN  1115.099976  2269.149902
# 2010-01-01  92.919998           NaN          NaN          NaN          NaN
# 2010-01-04  92.495003  10583.959961  5500.299805  1132.989990  2308.419922
# ...

# %%
yahoo_df['Adj Close'].describe()
# Out:
#           CHFUSD=X         CL=F        CNY=X     EURUSD=X     GBPUSD=X  \
# count  2982.000000  2880.000000  2912.000000  2985.000000  2985.000000
# mean      1.048316    69.167681     6.528076     1.222889     1.454508
# std       0.057927    22.771874     0.292815     0.109235     0.143444
# min       0.860067   -37.630001     5.863000     1.039047     1.149439
# 25%       1.010604    49.937499     6.280225     1.123848     1.309929
# 50%       1.039798    64.775002     6.495850     1.201043     1.492092
# 75%       1.086248    91.662502     6.789550     1.320481     1.579604
# max       1.383509   113.930000     7.178000     1.484406     1.716090
#
#               GC=F        JPY=X          ^DJI        ^FTSE        ^GSPC  \
# count  2879.000000  2985.000000   2902.000000  2905.000000  2902.000000
# mean   1404.811636   101.968894  19112.482833  6509.008155  2166.557976
# std     227.453743    13.302529   6294.742636   700.056063   777.677182
# ...

# %%
stocks_df=yahoo_df['Adj Close']

# %%
stocks_df.reset_index(inplace=True)

# %%
stocks_df.head()
# Out:
#         Date  CHFUSD=X       CL=F   CNY=X  EURUSD=X  GBPUSD=X         GC=F  \
# 0 2009-12-31  0.966931  79.360001  6.8305  1.432706  1.618202  1095.199951
# 1 2010-01-01  0.967211        NaN     NaN  1.438994  1.613294          NaN
# 2 2010-01-04  0.971723  81.510002  6.8169  1.442398  1.611370  1117.699951
# 3 2010-01-05  0.967399  81.769997  6.8170  1.436596  1.599079  1118.099976
# 4 2010-01-06  0.973141  83.180000  6.8183  1.440403  1.602384  1135.900024
#
#        JPY=X          ^DJI        ^FTSE        ^GSPC        ^IXIC
# 0  92.910004  10428.049805          NaN  1115.099976  2269.149902
# 1  92.919998           NaN          NaN          NaN          NaN
# 2  92.495003  10583.959961  5500.299805  1132.989990  2308.419922
# 3  91.584999  10572.019531  5522.500000  1136.520020  2308.709961
# 4  92.356003  10573.679688  5530.000000  1137.140015  2301.090088

# %%
# stocks_df.plot(x='Date',subplots=True, layout = (6,2), figsize=(15,10))

# %%
data = pd.merge(bitinfo_df, stocks_df, how ="outer", on='Date')

# %%
data.head()
# Out:
#    mining_profitability  transactions  market_cap  sent_addresses  \
# 0                   NaN           NaN         NaN             NaN
# 1                   NaN           NaN         NaN             NaN
# 2                   NaN           NaN         NaN             NaN
# 3                   NaN           NaN         NaN             NaN
# 4                   NaN           NaN         NaN             NaN
#
#    median_transaction_size  send_usd  hashrate  top_100_percent  \
# 0                      NaN       NaN       NaN              NaN
# 1                      NaN       NaN       NaN              NaN
# 2                      NaN       NaN       NaN              NaN
# 3                      NaN       NaN       NaN              NaN
# 4                      NaN       NaN       NaN              NaN
#
#    confirmation_time  block_size  tweets  av_transaction_value  difficulty  \
# 0                NaN       204.0     NaN                   NaN         1.0
# ...

# %%
data.plot(x='Date',subplots=True, layout = (10,3), figsize=(25,19))
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>],
# ...
