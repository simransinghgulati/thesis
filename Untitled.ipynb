# %%
import pandas as pd

# %%
data = pd.read_csv('data/btc_data.csv')

# %%
data
# Out:
#       Unnamed: 0        date  market_capitalisation      sent_usd  \
# 0           4023  2009-01-03                    NaN           NaN
# 1           4024  2009-01-04                    NaN           NaN
# 2           4025  2009-01-05                    NaN           NaN
# 3           4026  2009-01-06                    NaN           NaN
# 4           4027  2009-01-07                    NaN           NaN
# ...          ...         ...                    ...           ...
# 4579        4019  2021-07-18           5.958809e+11  7.945136e+09
# 4580        4020  2021-07-19           5.851150e+11  1.100123e+10
# 4581        4021  2021-07-20           5.597898e+11  1.260160e+10
# 4582        4022  2021-07-21           5.848672e+11  1.426411e+10
# 4583        4583  2021-07-22                    NaN           NaN
#
#       transactions  avg_transaction_value  median_transaction_value  \
# 0              NaN                    NaN                       NaN
# ...

# %%
data.plot(x='date',subplots=True, layout = (10,3), figsize=(25,19))
# Out:
# array([[<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
#        [<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#         <AxesSubplot:xlabel='date'>],
# ...
